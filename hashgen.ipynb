# %%
import hashlib
import os

# %%
random_data = os.urandom(32)
random_data
# Out:
# b'\x1e5^\xb3\xd9\xa1A\xd9\xb6\xf5\x11Q\xa7\xb1\xf7\xb1\xac\xb29\xd9/F\x01=\x07\x1f}\xd488\x13\xcb'

# %%
hash_object = hashlib.sha256(random_data)
hash_object
# Out:
# <sha256 _hashlib.HASH object @ 0x111966d70>

# %%
random_hash = hash_object.hexdigest()
random_hash
# Out:
# 'c22cebedf7a383340d4b34a084de2bc8e8e614a17a5e8405822b14f3846ab2eb'
